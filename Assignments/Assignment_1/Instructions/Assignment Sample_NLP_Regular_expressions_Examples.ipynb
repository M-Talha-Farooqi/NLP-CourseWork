# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/M-Talha-Farooqi/NLP-CourseWork/blob/main/Assignments/Assignment_1/Instructions/Assignment_Sample_NLP_Regular_expressions_Examples.ipynb)

# %% [markdown]
# # Understanding of Regular Expressions

# %% [markdown]
# # 🧠 Introduction to Regular Expressions (Regex) in Python
#
# ## 🔍 What is a Regular Expression?
#
# A **Regular Expression (Regex)** is a sequence of characters used to search, match, or manipulate text using **pattern matching**. It's extremely useful for text processing tasks like:
#
# - Finding specific patterns (e.g., hashtags, email addresses)
# - Replacing parts of text (e.g., removing mentions)
# - Validating inputs (e.g., phone numbers)
#
# ---
#
# ## ✨ Common Regex Patterns
#
# | Pattern       | Description                             | Example Match          |
# |---------------|------------------------------------------|------------------------|
# | `\d+`         | One or more digits                       | `2023`, `45`           |
# | `\w+`         | One or more word characters (letters, digits, underscore) | `hello`, `abc_123` |
# | `\bword\b`    | Whole word match                         | `word` but not `sword` |
# | `#\w+`        | Hashtags                                 | `#TerrorAlert`         |
# | `@\w+`        | Mentions                                 | `@IntelWatch`          |
# | `[A-Z]{2,}`   | Two or more uppercase letters            | `ALERT`, `SOS`         |
# | `^` / `$`     | Start / end of string                    | Useful in validation   |
# | `.`           | Any character (except newline)           | `a.b` matches `aab`, `acb` |
# | `*`, `+`, `?` | Quantifiers (`*`: 0+, `+`: 1+, `?`: 0 or 1) | `lo+l` → `lol`, `lool` |
# | `()`          | Grouping                                | Used for capturing      |
#
# ---

# %%
import pandas as pd
import re

# Sample dataset
data = {
    'ID': [1, 2],
    'Text': [
        "We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!",
        "Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details."
    ]
}

# Show entire text without truncation
pd.set_option('display.max_colwidth', None)  

df = pd.DataFrame(data)
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.

# %%
# Regular Expressions

# 1. Extract Hashtags
df['Hashtags'] = df['Text'].str.findall(r'#\w+') 
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#          Hashtags
# 0        [#Kabul]
# 1  [#TerrorAlert]

# %%
# 2. Extract Mentions (@usernames)
df['Mentions'] = df['Text'].str.findall(r'@\w+')
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#          Hashtags       Mentions
# 0        [#Kabul]  [@IntelWatch]
# 1  [#TerrorAlert]     [@CT_Unit]

# %%
# 3. Extract Numbers
df['Numbers'] = df['Text'].str.findall(r'\d+')
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#          Hashtags       Mentions    Numbers
# 0        [#Kabul]  [@IntelWatch]  [3, 2023]
# 1  [#TerrorAlert]     [@CT_Unit]        [2]

# %%
# 6. Extract Terror-related Words (like bombings, terrorists)
df['Terror_Keywords'] = df['Text'].str.findall(r'\b(bombings?|terrorists?|airport)\b')
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#          Hashtags       Mentions    Numbers        Terror_Keywords
# 0        [#Kabul]  [@IntelWatch]  [3, 2023]             [bombings]
# 1  [#TerrorAlert]     [@CT_Unit]        [2]  [terrorists, airport]

# %%
# 7. Check if Tweet contains "alert" (case-insensitive)
df['Contains_Alert'] = df['Text'].str.contains(r'alert', flags=re.IGNORECASE)
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#          Hashtags       Mentions    Numbers        Terror_Keywords  \
# 0        [#Kabul]  [@IntelWatch]  [3, 2023]             [bombings]
# 1  [#TerrorAlert]     [@CT_Unit]        [2]  [terrorists, airport]
#
#    Contains_Alert
# 0           False
# 1            True

# %%
# \b: This is the word boundary metacharacter.
# \w: This metacharacter stands for "word character".
df['Words_Start_A'] = df['Text'].str.findall(r'\b[aA]\w*')

# Show full DataFrame
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#          Hashtags       Mentions    Numbers        Terror_Keywords  \
# 0        [#Kabul]  [@IntelWatch]  [3, 2023]             [bombings]
# 1  [#TerrorAlert]     [@CT_Unit]        [2]  [terrorists, airport]
#
#    Contains_Alert     Words_Start_A
# 0           False                []
# 1            True  [Alert, airport]

# %% [markdown]
# # Preprocessing of Data using RE

# %%
import pandas as pd
import re
import string

# Sample dataset
data = {
    'ID': [1, 2],
    'Text': [
        "We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!",
        "Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details."
    ]
}

df = pd.DataFrame(data)
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.

# %%
# Step 1: Lowercase
def to_lowercase(text):
    return text.lower()

# Apply each step one by one to a new column
df['Lowercase'] = df['Text'].apply(to_lowercase)
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#                                                                                          Lowercase
# 0    we can't ignore the 3 bombings in #kabul last week – @intelwatch says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact @ct_unit for details.

# %%
# Step 2: Remove usernames (@username)
def remove_usernames(text):
    return re.sub(r'@\w+', '', text)

df['No_Usernames'] = df['Lowercase'].apply(remove_usernames)
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#                                                                                          Lowercase  \
# 0    we can't ignore the 3 bombings in #kabul last week – @intelwatch says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact @ct_unit for details.
#
#                                                                               No_Usernames
# 0       we can't ignore the 3 bombings in #kabul last week –  says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact  for details.

# %%
# Step 3: Remove hashtags (#hashtag)
def remove_hashtags(text):
    return re.sub(r'#\w+', '', text)
    
df['No_Hashtags'] = df['No_Usernames'].apply(remove_hashtags)
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#                                                                                          Lowercase  \
# 0    we can't ignore the 3 bombings in #kabul last week – @intelwatch says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact @ct_unit for details.
#
#                                                                               No_Usernames  \
# 0       we can't ignore the 3 bombings in #kabul last week –  says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact  for details.
#
#                                                                     No_Hashtags
# 0  we can't ignore the 3 bombings in  last week –  says it's the worst in 2023!
# 1   alert: 2 terrorists were defused near the airport!!   contact  for details.

# %%
import contractions
# Function 1: Expanding contractions
def expand_contractions(text):
    return contractions.fix(text)

df['No_Contractions'] = df['No_Hashtags'].apply(expand_contractions)
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#                                                                                          Lowercase  \
# 0    we can't ignore the 3 bombings in #kabul last week – @intelwatch says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact @ct_unit for details.
#
#                                                                               No_Usernames  \
# 0       we can't ignore the 3 bombings in #kabul last week –  says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact  for details.
#
#                                                                     No_Hashtags  \
# 0  we can't ignore the 3 bombings in  last week –  says it's the worst in 2023!
# 1   alert: 2 terrorists were defused near the airport!!   contact  for details.
#
#                                                                   No_Contractions
# 0  we cannot ignore the 3 bombings in  last week –  says it is the worst in 2023!
# 1     alert: 2 terrorists were defused near the airport!!   contact  for details.

# %%
# Step 5: Remove numbers
def remove_numbers(text):
    return re.sub(r'\d+', '', text) 
    
df['No_Numbers'] = df['No_Contractions'].apply(remove_numbers)
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#                                                                                          Lowercase  \
# 0    we can't ignore the 3 bombings in #kabul last week – @intelwatch says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact @ct_unit for details.
#
#                                                                               No_Usernames  \
# 0       we can't ignore the 3 bombings in #kabul last week –  says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact  for details.
#
#                                                                     No_Hashtags  \
# 0  we can't ignore the 3 bombings in  last week –  says it's the worst in 2023!
# 1   alert: 2 terrorists were defused near the airport!!   contact  for details.
#
#                                                                   No_Contractions  \
# 0  we cannot ignore the 3 bombings in  last week –  says it is the worst in 2023!
# 1     alert: 2 terrorists were defused near the airport!!   contact  for details.
#
#                                                                    No_Numbers
# 0   we cannot ignore the  bombings in  last week –  says it is the worst in !
# 1  alert:  terrorists were defused near the airport!!   contact  for details.

# %%
# Tokenizer helper (split into words)
def tokenize(text):
    return text.split()

# Function 6: Removing special characters per token
def remove_special_characters(text):
    tokens = tokenize(text)
    return ' '.join([re.sub(r'[^A-Za-z0-9]+', '', word) for word in tokens if word]) 
    
df['No_SpecialChars'] = df['No_Numbers'].apply(remove_special_characters)
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#                                                                                          Lowercase  \
# 0    we can't ignore the 3 bombings in #kabul last week – @intelwatch says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact @ct_unit for details.
#
#                                                                               No_Usernames  \
# 0       we can't ignore the 3 bombings in #kabul last week –  says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact  for details.
#
#                                                                     No_Hashtags  \
# 0  we can't ignore the 3 bombings in  last week –  says it's the worst in 2023!
# 1   alert: 2 terrorists were defused near the airport!!   contact  for details.
#
#                                                                   No_Contractions  \
# 0  we cannot ignore the 3 bombings in  last week –  says it is the worst in 2023!
# 1     alert: 2 terrorists were defused near the airport!!   contact  for details.
#
#                                                                    No_Numbers  \
# 0   we cannot ignore the  bombings in  last week –  says it is the worst in !
# 1  alert:  terrorists were defused near the airport!!   contact  for details.
#
#                                                         No_SpecialChars
# 0  we cannot ignore the bombings in last week  says it is the worst in
# 1    alert terrorists were defused near the airport contact for details

# %%
# Step 7: Remove extra whitespace
def remove_extra_whitespace(text):
    return re.sub(r'\s+', ' ', text).strip() 

df['Cleaned_Text'] = df['No_SpecialChars'].apply(remove_extra_whitespace)
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#                                                                                          Lowercase  \
# 0    we can't ignore the 3 bombings in #kabul last week – @intelwatch says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact @ct_unit for details.
#
#                                                                               No_Usernames  \
# 0       we can't ignore the 3 bombings in #kabul last week –  says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact  for details.
#
#                                                                     No_Hashtags  \
# 0  we can't ignore the 3 bombings in  last week –  says it's the worst in 2023!
# 1   alert: 2 terrorists were defused near the airport!!   contact  for details.
#
#                                                                   No_Contractions  \
# 0  we cannot ignore the 3 bombings in  last week –  says it is the worst in 2023!
# 1     alert: 2 terrorists were defused near the airport!!   contact  for details.
#
#                                                                    No_Numbers  \
# 0   we cannot ignore the  bombings in  last week –  says it is the worst in !
# 1  alert:  terrorists were defused near the airport!!   contact  for details.
#
#                                                         No_SpecialChars  \
# 0  we cannot ignore the bombings in last week  says it is the worst in
# 1    alert terrorists were defused near the airport contact for details
#
#                                                          Cleaned_Text
# 0  we cannot ignore the bombings in last week says it is the worst in
# 1  alert terrorists were defused near the airport contact for details

# %%
import pandas as pd
from nltk.corpus import stopwords

# Make sure you have the stopwords downloaded
# import nltk
# nltk.download('stopwords')

df['Cleaned_Text'] = df['Cleaned_Text'].apply(word_tokenize)

# Get the set of English stopwords
stop_words = set(stopwords.words('english'))
stop_words

# Define a function to remove stopwords
def remove_stopwords(tokens):
    return [word for word in tokens if word.lower() not in stop_words]

# Apply the function to the 'tokens' column
df['Cleaned_Text'] = df['Cleaned_Text'].apply(remove_stopwords)
df
# Out:
#    ID  \
# 0   1
# 1   2
#
#                                                                                               Text  \
# 0    We can't ignore the 3 bombings in #Kabul last week – @IntelWatch says it's the worst in 2023!
# 1  Alert: 2 terrorists were defused near the airport!! #TerrorAlert  Contact @CT_Unit for details.
#
#                                                                                          Lowercase  \
# 0    we can't ignore the 3 bombings in #kabul last week – @intelwatch says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact @ct_unit for details.
#
#                                                                               No_Usernames  \
# 0       we can't ignore the 3 bombings in #kabul last week –  says it's the worst in 2023!
# 1  alert: 2 terrorists were defused near the airport!! #terroralert  contact  for details.
#
#                                                                     No_Hashtags  \
# 0  we can't ignore the 3 bombings in  last week –  says it's the worst in 2023!
# 1   alert: 2 terrorists were defused near the airport!!   contact  for details.
#
#                                                                   No_Contractions  \
# 0  we cannot ignore the 3 bombings in  last week –  says it is the worst in 2023!
# 1     alert: 2 terrorists were defused near the airport!!   contact  for details.
#
#                                                                    No_Numbers  \
# 0   we cannot ignore the  bombings in  last week –  says it is the worst in !
# 1  alert:  terrorists were defused near the airport!!   contact  for details.
#
#                                                         No_SpecialChars  \
# 0  we cannot ignore the bombings in last week  says it is the worst in
# 1    alert terrorists were defused near the airport contact for details
#
#                                                     Cleaned_Text
# 0                    [ignore, bombings, last, week, says, worst]
# 1  [alert, terrorists, defused, near, airport, contact, details]
